# %% [markdown]
# # Getting started

# %% [markdown]
# ## 1. Data

# %%
import pandas as pd
import numpy as np 
from flask import Flask
import openai

pd.set_option('display.max_colwidth', None)

# %%
data_sample = pd.read_csv("../data/twitter_data_clean_sample.csv")

# %%
data_sample.head()
# Out:
#                                                                                                                                  customer_tweet  \
# 0                                Ordered this around 2am Friday morning and it made it here already... good job @115830 https://t.co/XXMuII3QwQ
# 1   @AmazonHelp what does "ships in 1-3 weeks" actually mean? Do you have the item I want in stock or not? Items like this have given me issues
# 2         @115821 // Email from Representative not correct.  There was someone to receive package.  Whoever said different at @118706 is lying.
# 3                                                         je l’ai déjà l’application amazon jdevrais être immunisé de vos pubs de merde @115821
# 4  I must say @115830, a package left under a doormat which is full of holes, in the middle of a downpour, is not the best idea #wetelectronics
#
#                                                                                                                                                                                                                             company_tweet  \
# 0                                                                                                                                                            @383517 I am very happy to hear this Pablo:) I hope you enjoy your order.^GA
# 1                                                              @274096 If your item will ship in 1-3 weeks, this means the item is not in stock and needs to be ordered from our distributor. More info here: https://t.co/V7JYyWd9JF ^RA
# 2                                                                                                             @528375 I'm sorry you haven't received your package. We'd like to help. Please contact us here: https://t.co/hApLpMlfHN ^AY
# 3                                 @792999 3/3  Ensuite décochez à nouveau les cases que vous aviez sélectionnées.  N'oubliez pas de "Valider" pour effectuer vos modifications.  \nNous espérons que ces informations vous seront utiles.
# 4  @776873 I apologize for how your delivery was handled, that is not the experience we want our customers to have. Which courier was assigned delivery of that package, as shown in the order details here:  https://t.co/aaDyEz1VgE ^CH
#
#       company
# 0  AmazonHelp
# 1  AmazonHelp
# 2  AmazonHelp
# 3  AmazonHelp
# 4  AmazonHelp

# %%
data_sample.company.value_counts()
# Out:
# company
# AmazonHelp      100
# AppleSupport    100
# SpotifyCares    100
# Uber_Support    100
# Name: count, dtype: int64

# %% [markdown]
# ## 2. How to use the OpenAI API

# %% [markdown]
# Create a `config.ini` file containing your OpenAI API credentials
#
#
#     [OPENAI_API]
#     OPENAI_KEY = key

# %%
import configparser
from openai import OpenAI

# %%
# Loading OpenAI API key from configuration file
config = configparser.ConfigParser()
config.read('../config.ini') #Path to your configuration file
OPENAI_KEY = config.get('OPENAI_API', 'OPENAI_KEY')

# %%
client = OpenAI(api_key=OPENAI_KEY)

# %% [markdown]
# ### ChatCompletion : Get GPT response to your prompt

# %% [markdown]
# #### Documentation : https://platform.openai.com/docs/guides/text-generation/chat-completions-api

# %%
message = data_sample.head(1).customer_tweet[0]
company = data_sample.head(1).company[0]

print(f"Tweet: {message} \nCompany: {company}")
# Out:
# Tweet: Ordered this around 2am Friday morning and it made it here already... good job @115830 https://t.co/XXMuII3QwQ
# Company: AmazonHelp

# %%
instruction =  f"""\
You are a chatbot answering customer's messages. You are working for a company called {company}. Reply to the message below.
#####
Message:
"{message}" """
print(f"Instruction:\n\n{instruction}")
# Out:
# Instruction:
#
# You are a chatbot answering customer's messages. You are working for a company called AmazonHelp. Reply to the message below.
# #####
# Message:
# "Ordered this around 2am Friday morning and it made it here already... good job @115830 https://t.co/XXMuII3QwQ"

# %%
messages = [
    {"role": "user", "content": instruction}
]

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=messages,
    temperature = 0.7) # temperature ranges from 0 (deterministic) to 1 (creative)

# %%
generated_text = response.choices[0].message.content
print(f"Answer generated:\n\n{generated_text}")
# Out:
# Answer generated:
#
# Thank you for sharing your positive feedback! We're glad to hear that your order arrived quickly. If you have any questions or need assistance with anything else, feel free to reach out to us. Enjoy your purchase! 😊 #AmazonHelp

# %% [markdown]
# ### Embedding model : Get the embedding of a text

# %% [markdown]
# #### Documentation : https://platform.openai.com/docs/guides/embeddings

# %%
message_1 = "Ordered that pair of shoes around 2am Friday morning and it made it here already... good job"
message_2 = "Placed an order for some headphones early Monday morning, and they've arrived in 2 days... impressive service!"
message_3 = "I hate Amazon!!!"

# %%
def get_embedding(text, model="text-embedding-3-small"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
embedding_message_1 = get_embedding(message_1)
embedding_message_2 = get_embedding(message_2)
embedding_message_3 = get_embedding(message_3)

# %%
print(f"Message 1 : {message_1}\nEmbedding length : {len(embedding_message_1)}\nEmbedding:\n{embedding_message_1}")
# Out:
# Message 1 : Ordered that pair of shoes around 2am Friday morning and it made it here already... good job
# Embedding length : 1536
# Embedding:
# [0.024054376408457756, -0.007412675302475691, -0.057449985295534134, -0.028037725016474724, 0.012272641062736511, -0.028724992647767067, 0.018191561102867126, 0.013927694410085678, -0.03983348608016968, -0.04230204224586487, -0.006595667917281389, 0.020688166841864586, -0.05043704807758331, -0.0297068040817976, -0.03276444599032402, -0.011129532009363174, 0.029650701209902763, -0.009327207691967487, -0.06962444633245468, 0.04502306133508682, -0.005659440997987986, -0.022469453513622284, 0.020281415432691574, -0.028276165947318077, -0.02561124786734581, -0.016704818233847618, 0.025274626910686493, -0.0163681972771883, 0.02382996305823326, -0.006746446248143911, 0.021038813516497612, -0.02967875264585018, 0.06373357772827148, -0.036663640290498734, 0.00189174001570791, 0.0239702221006155, -0.02312866970896721, 0.03425118699669838, -0.03223146125674248, 0.025064239278435707, -0.006385279819369316, -0.016760921105742455, 0.01887882873415947, -0.014376522041857243, -0.01962219923734665, 0.027013836428523064, 0.008085917681455612, 0.0359903983771801, -0.004663603845983744, 0.07691790163516998, 0.0555424690246582, -0.007658128160983324, -0.04883809760212898, 0.015456514433026314, 0.014243276789784431, -0.02709799073636532, 0.015021712519228458, 0.03523299843072891, 0.04634149372577667, -0.030772771686315536, -0.0110523896291852, -0.03596234321594238, -0.015246126800775528, 0.012987961061298847, 0.009060715325176716, -0.05102613568305969, -0.0114801786839962, 0.01875259540975094, -0.02984706312417984, -0.01506379060447216, 0.02368970401585102, 0.03983348608016968, -0.010049539618194103, -0.06463123112916946, 0.022623736411333084, 0.007826438173651695, 0.023044513538479805, 0.022315168753266335, -0.010912131518125534, 0.054364293813705444, -0.030604461207985878, -0.054504550993442535, -0.015540669672191143, -0.01469911728054285, -0.047211095690727234, -0.07170027494430542, -0.09548816084861755, 0.0377015545964241, -0.049819909036159515, -0.0634530633687973, -0.016017550602555275, 0.041179969906806946, 0.044405922293663025, 0.026733318343758583, 0.016284041106700897, -0.010259928181767464, -0.03977738320827484, 0.0297068040817976, 0.03439144790172577, -0.018387923017144203, 0.04780018329620361, -0.02002895064651966, 0.005747102666646242, -0.016746895387768745, 0.01756039634346962, 0.03116549551486969, 0.004523344803601503, -0.040590882301330566, -0.022357245907187462, -0.06098450720310211, -0.02765902690589428, -0.06244319677352905, 0.02604605071246624, 0.0453035794198513, 0.054336242377758026, 0.03803817555308342, 0.04370462894439697, 0.008857340551912785, 0.04743551090359688, -0.00141661346424371, -0.010498368181288242, -0.01814948208630085, -0.03346573933959007, -0.0114030372351408, -0.04179710894823074, 0.0009791813790798187, -0.0426667146384716, -0.025709429755806923, -0.005459572188556194, -0.0014315159060060978, -0.030351994559168816, -0.03369015455245972, 0.05223236232995987, -0.027294354513287544, -0.043816834688186646, -0.011795761063694954, -0.008436564356088638, -0.04348021373152733, -0.04743551090359688, 0.002770110499113798, 0.005256196949630976, -0.04331190511584282, 0.028065776452422142, 0.0022090754937380552, -0.0017321956111118197, -0.010673691518604755, 0.00046241559903137386, 0.04255450516939163, -0.0031417962163686752, 0.003322379197925329, -0.021389460191130638, -6.119883619248867e-05, 0.01103836391121149, -0.0026070596650242805, 0.004274385515600443, 0.007209300063550472, 0.00636774767190218, 0.04993211850523949, 0.02967875264585018, -0.005673466715961695, -0.026130206882953644, 0.012412900105118752, -0.012791598215699196, 0.0018619350157678127, 0.04106776416301727, -0.008219162933528423, 0.0262143611907959, 0.01768662966787815, -0.07652517408132553, -0.03220340982079506, 0.02751876786351204, 0.04583656042814255, 0.013072116300463676, 0.023030487820506096, 0.0036607536021620035, -0.027392534539103508, -0.017013387754559517, 0.019860640168190002, -0.03573793172836304, -0.021852314472198486, -0.005108925048261881, - ...

# %% [markdown]
# #### Compare two embeddings to find similarity

# %% [markdown]
# A cosine similarity close to 1 implies that the sentence embeddings are very similar, meaning their vectors point in almost the same direction. This suggests the sentences have similar meanings or semantic content.
#
# A cosine similarity around 0 indicates that the sentence embeddings are orthogonal (or near-orthogonal) to each other in the vector space, suggesting that the sentences are unrelated or have neutral similarity.
#
# A cosine similarity close to -1 indicates that the embeddings are diametrically opposed in the vector space, suggesting that the sentences are highly dissimilar or have opposite meanings.

# %%
import numpy as np

def cosine_similarity(A, B):
    dot_product = np.dot(A, B)
    magnitude_A = np.linalg.norm(A)
    magnitude_B = np.linalg.norm(B)
    return dot_product / (magnitude_A * magnitude_B)

# %%
similarity_message1_message2 = cosine_similarity(embedding_message_1, embedding_message_2)
print(f"Message 1 : {message_1}\nMessage 2 : {message_2}\n\nSimilarity: {similarity_message1_message2}")
# Out:
# Message 1 : Ordered that pair of shoes around 2am Friday morning and it made it here already... good job
# Message 2 : Placed an order for some headphones early Monday morning, and they've arrived in 2 days... impressive service!
#
# Similarity: 0.5958406184122572

# %%
similarity_message1_message3 = cosine_similarity(embedding_message_1, embedding_message_3)
print(f"Message 1 : {message_1}\nMessage 3 : {message_3}\n\nSimilarity: {similarity_message1_message3}")
# Out:
# Message 1 : Ordered that pair of shoes around 2am Friday morning and it made it here already... good job
# Message 3 : I hate Amazon!!!
#
# Similarity: 0.16232099289477625
